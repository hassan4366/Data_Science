# %%
import pandas as pd
df = pd.read_csv('students_dropout_academic_success.csv')

# %%
df.head(5)
# Out:
#    Marital Status  Application mode  Application order  Course  \
# 0               1                17                  5     171
# 1               1                15                  1    9254
# 2               1                 1                  5    9070
# 3               1                17                  2    9773
# 4               2                39                  1    8014
#
#    Daytime/evening attendance  Previous qualification  \
# 0                           1                       1
# 1                           1                       1
# 2                           1                       1
# 3                           1                       1
# 4                           0                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                           122.0            1                      19
# 1                           160.0            1                       1
# ...

# %%
df.tail()
# Out:
#       Marital Status  Application mode  Application order  Course  \
# 4419               1                 1                  6    9773
# 4420               1                 1                  2    9773
# 4421               1                 1                  1    9500
# 4422               1                 1                  1    9147
# 4423               1                10                  1    9773
#
#       Daytime/evening attendance  Previous qualification  \
# 4419                           1                       1
# 4420                           1                       1
# 4421                           1                       1
# 4422                           1                       1
# 4423                           1                       1
#
#       Previous qualification (grade)  Nacionality  Mother's qualification  \
# 4419                           125.0            1                       1
# ...

# %%
df.shape
# Out:
# (4424, 37)

# %%
df['Marital Status']
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       2
#        ..
# 4419    1
# 4420    1
# 4421    1
# 4422    1
# 4423    1
# Name: Marital Status, Length: 4424, dtype: int64

# %%
#use loc and iloc
df.loc[2]
# Out:
# Marital Status                                          1
# Application mode                                        1
# Application order                                       5
# Course                                               9070
# Daytime/evening attendance                              1
# Previous qualification                                  1
# Previous qualification (grade)                      122.0
# Nacionality                                             1
# Mother's qualification                                 37
# Father's qualification                                 37
# Mother's occupation                                     9
# Father's occupation                                     9
# Admission grade                                     124.8
# Displaced                                               1
# Educational special needs                               0
# Debtor                                                  0
# ...

# %%
df.iloc[:, 2]
# Out:
# 0       5
# 1       1
# 2       5
# 3       2
# 4       1
#        ..
# 4419    6
# 4420    2
# 4421    1
# 4422    1
# 4423    1
# Name: Application order, Length: 4424, dtype: int64

# %%
df.loc[: ,[ 'Marital Status', 'Application mode', 'Application order']]
# Out:
#       Marital Status  Application mode  Application order
# 0                  1                17                  5
# 1                  1                15                  1
# 2                  1                 1                  5
# 3                  1                17                  2
# 4                  2                39                  1
# ...              ...               ...                ...
# 4419               1                 1                  6
# 4420               1                 1                  2
# 4421               1                 1                  1
# 4422               1                 1                  1
# 4423               1                10                  1
#
# [4424 rows x 3 columns]

# %%
df.iloc[1:4]
# Out:
#    Marital Status  Application mode  Application order  Course  \
# 1               1                15                  1    9254
# 2               1                 1                  5    9070
# 3               1                17                  2    9773
#
#    Daytime/evening attendance  Previous qualification  \
# 1                           1                       1
# 2                           1                       1
# 3                           1                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 1                           160.0            1                       1
# 2                           122.0            1                      37
# 3                           122.0            1                      38
#
#    Father's qualification  ...  Curricular units 2nd sem (credited)  \
# 1                       3  ...                                    0
# ...

# %%
df.loc[1:4]
# Out:
#    Marital Status  Application mode  Application order  Course  \
# 1               1                15                  1    9254
# 2               1                 1                  5    9070
# 3               1                17                  2    9773
# 4               2                39                  1    8014
#
#    Daytime/evening attendance  Previous qualification  \
# 1                           1                       1
# 2                           1                       1
# 3                           1                       1
# 4                           0                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 1                           160.0            1                       1
# 2                           122.0            1                      37
# 3                           122.0            1                      38
# 4                           100.0            1                      37
#
# ...

# %%
df.rename(columns={'Curricular units 2nd sem (credited)':'Summary units 2nd'})
# Out:
#       Marital Status  Application mode  Application order  Course  \
# 0                  1                17                  5     171
# 1                  1                15                  1    9254
# 2                  1                 1                  5    9070
# 3                  1                17                  2    9773
# 4                  2                39                  1    8014
# ...              ...               ...                ...     ...
# 4419               1                 1                  6    9773
# 4420               1                 1                  2    9773
# 4421               1                 1                  1    9500
# 4422               1                 1                  1    9147
# 4423               1                10                  1    9773
#
#       Daytime/evening attendance  Previous qualification  \
# 0                              1                       1
# ...

# %%
df.loc[df["Mother's qualification"] < 35]
# Out:
#       Marital Status  Application mode  Application order  Course  \
# 0                  1                17                  5     171
# 1                  1                15                  1    9254
# 6                  1                 1                  1    9500
# 8                  1                 1                  3    9238
# 9                  1                 1                  1    9238
# ...              ...               ...                ...     ...
# 4414               1                 1                  1    9130
# 4417               1                 1                  1    9070
# 4418               1                44                  1    9070
# 4419               1                 1                  6    9773
# 4420               1                 1                  2    9773
#
#       Daytime/evening attendance  Previous qualification  \
# 0                              1                       1
# ...

# %%
df.loc[(df["Father's qualification"] > 30) & (df["Mother's qualification"] > 35)]
# Out:
#       Marital Status  Application mode  Application order  Course  \
# 2                  1                 1                  5    9070
# 3                  1                17                  2    9773
# 4                  2                39                  1    8014
# 5                  2                39                  1    9991
# 7                  1                18                  4    9254
# ...              ...               ...                ...     ...
# 4415               4                39                  1    9500
# 4416               1                43                  2    9500
# 4421               1                 1                  1    9500
# 4422               1                 1                  1    9147
# 4423               1                10                  1    9773
#
#       Daytime/evening attendance  Previous qualification  \
# 2                              1                       1
# ...

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of       Marital Status  Application mode  Application order  Course  \
# 0                  1                17                  5     171
# 1                  1                15                  1    9254
# 2                  1                 1                  5    9070
# 3                  1                17                  2    9773
# 4                  2                39                  1    8014
# ...              ...               ...                ...     ...
# 4419               1                 1                  6    9773
# 4420               1                 1                  2    9773
# 4421               1                 1                  1    9500
# 4422               1                 1                  1    9147
# 4423               1                10                  1    9773
#
#       Daytime/evening attendance  Previous qualification  \
# 0                              1                       1
# ...

# %%
df.isnull().sum(axis =0)
# Out:
# Marital Status                                    0
# Application mode                                  0
# Application order                                 0
# Course                                            0
# Daytime/evening attendance                        0
# Previous qualification                            0
# Previous qualification (grade)                    0
# Nacionality                                       0
# Mother's qualification                            0
# Father's qualification                            0
# Mother's occupation                               0
# Father's occupation                               0
# Admission grade                                   0
# Displaced                                         0
# Educational special needs                         0
# Debtor                                            0
# Tuition fees up to date                           0
# Gender                                            0
# ...

# %%
df['Application mode'].value_counts()
# Out:
# Application mode
# 1     1708
# 17     872
# 39     785
# 43     312
# 44     213
# 7      139
# 18     124
# 42      77
# 51      59
# 16      38
# 53      35
# 15      30
# 5       16
# 10      10
# 2        3
# 57       1
# 26       1
# 27       1
# Name: count, dtype: int64

# %%
df.isna().sum()* 100 / len(df)
# Out:
# Marital Status                                    0.0
# Application mode                                  0.0
# Application order                                 0.0
# Course                                            0.0
# Daytime/evening attendance                        0.0
# Previous qualification                            0.0
# Previous qualification (grade)                    0.0
# Nacionality                                       0.0
# Mother's qualification                            0.0
# Father's qualification                            0.0
# Mother's occupation                               0.0
# Father's occupation                               0.0
# Admission grade                                   0.0
# Displaced                                         0.0
# Educational special needs                         0.0
# Debtor                                            0.0
# Tuition fees up to date                           0.0
# ...

# %%
print(df.dtypes)
# Out:
# Marital Status                                      int64
# Application mode                                    int64
# Application order                                   int64
# Course                                              int64
# Daytime/evening attendance                          int64
# Previous qualification                              int64
# Previous qualification (grade)                    float64
# Nacionality                                         int64
# Mother's qualification                              int64
# Father's qualification                              int64
# Mother's occupation                                 int64
# Father's occupation                                 int64
# Admission grade                                   float64
# Displaced                                           int64
# Educational special needs                           int64
# Debtor                                              int64
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of       Marital Status  Application mode  Application order  Course  \
# 0                  1                17                  5     171
# 1                  1                15                  1    9254
# 2                  1                 1                  5    9070
# 3                  1                17                  2    9773
# 4                  2                39                  1    8014
# ...              ...               ...                ...     ...
# 4419               1                 1                  6    9773
# 4420               1                 1                  2    9773
# 4421               1                 1                  1    9500
# 4422               1                 1                  1    9147
# 4423               1                10                  1    9773
#
#       Daytime/evening attendance  Previous qualification  \
# 0                              1                       1
# ...

# %%
df.describe()
# Out:
#        Marital Status  Application mode  Application order       Course  \
# count     4424.000000       4424.000000        4424.000000  4424.000000
# mean         1.178571         18.669078           1.727848  8856.642631
# std          0.605747         17.484682           1.313793  2063.566416
# min          1.000000          1.000000           0.000000    33.000000
# 25%          1.000000          1.000000           1.000000  9085.000000
# 50%          1.000000         17.000000           1.000000  9238.000000
# 75%          1.000000         39.000000           2.000000  9556.000000
# max          6.000000         57.000000           9.000000  9991.000000
#
#        Daytime/evening attendance  Previous qualification  \
# count                 4424.000000             4424.000000
# mean                     0.890823                4.577758
# std                      0.311897               10.216592
# min                      0.000000                1.000000
# ...

# %%
df["Marital Status"].sort_values()
# Out:
# 0       1
# 2820    1
# 2821    1
# 2822    1
# 2823    1
#        ..
# 2914    6
# 2915    6
# 1180    6
# 1572    6
# 2767    6
# Name: Marital Status, Length: 4424, dtype: int64

# %%
#تعرض قيمه عشوائيه 
df.sample(4)
# Out:
#       Marital Status  Application mode  Application order  Course  \
# 2472               1                 1                  1    9670
# 2968               1                39                  2    8014
# 1223               2                39                  1    8014
# 3765               1                 1                  1    9500
#
#       Daytime/evening attendance  Previous qualification  \
# 2472                           1                       1
# 2968                           0                       1
# 1223                           0                      19
# 3765                           1                       1
#
#       Previous qualification (grade)  Nacionality  Mother's qualification  \
# 2472                           120.0            1                       1
# 2968                           100.0            1                      35
# 1223                           100.0            1                       1
# ...

# %%
df.pivot_table(index= 'Marital Status',values= ['Course','Previous qualification (grade)'], aggfunc= {'Course': 'median', 'Previous qualification (grade)': 'mean'})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 df.pivot_table(index= 'name',values= ['Course','Previous qualification (grade)'], aggfunc= {'Course': 'median', 'Previous qualification (grade)': 'mean'})
#
# File /lib/python3.12/site-packages/pandas/core/frame.py:9509, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    9492 @Substitution("")
#    9493 @Appender(_shared_docs["pivot_table"])
#    9494 def pivot_table(
#    (...)
#    9505     sort: bool = True,
#    9506 ) -> DataFrame:
#    9507     from pandas.core.reshape.pivot import pivot_table
# -> 9509     return pivot_table(
#    9510         self,
#    9511         values=values,
#    9512         index=index,
#    9513         columns=columns,
#    9514         aggfunc=aggfunc,
# ...
